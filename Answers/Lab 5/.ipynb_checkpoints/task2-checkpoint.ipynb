# %%
import json
import folium
import pandas as pd
import requests
import branca

# %%
sensor = pd.read_csv('sensors.csv')

# %%
sensor
# Out:
#      sensor_name  latitude  longitude               app_id            dev_id  \
# 0     Elsys ELT2   60.5790    15.0652  campusborlangeelsys  a81758fffe0459fd
# 1     Elsys ELT2   60.4886    15.3883  campusborlangeelsys  a81758fffe0459fe
# 2  Elsys ERS CO2   60.4878    15.4088  campusborlangeelsys  a81758fffe045fa4
# 3  Elsys ERS CO2   60.4877    15.4092  campusborlangeelsys  a81758fffe045fa5
# 4          ESP32   60.4887    15.3883          hajo66-test      paxcounter_1
# 5          ESP32   60.4888    15.3883          hajo66-test  weatherstation_1
# 6        Arduino   60.4877    15.4090          hajo66-test         arduino_1
#
#      install_time          adress  number  zip_code      city status  \
# 0  19-10-19 19:54      Gagnefsbyn      33     78400    Gagnef     OK
# 1  19-10-19 19:54  Mats knuts vag      68     78450  Borlange     OK
# 2  19-10-19 20:54      Roda vagen       3     78400  Borlange     OK
# 3  19-10-19 20:54      Roda vagen       3     78400  Borlange     OK
# 4  19-11-19 20:54  Mats knuts vag      68     78450  Borlange     OK
# 5  19-11-19 20:54  Mats knuts vag      68     78450  Borlange     OK
# 6  19-10-01 20:54      Roda vagen       3     78400  Borlange   FAIL
#
#                                             activity  additional_details  \
# 0  AccMotion, humidity, pressure, temperature, vd...                 NaN
# 1  AccMotion, humidity, pressure, temperature, vd...                 NaN
# 2     CO2, humidity, light, motion, temperature, vdd                 NaN
# 3     CO2, humidity, light, motion, temperature, vdd                 NaN
# 4                                         PaxCounter                 NaN
# 5                    humidity, pressure, temperature                 NaN
# 6                                          MQTT-test                 NaN
#
#    Unnamed: 13  Unnamed: 14  Unnamed: 15  Unnamed: 16  Unnamed: 17  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
# 5          NaN          NaN          NaN          NaN          NaN
# 6          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 18  Unnamed: 19
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN
# 5          NaN          NaN
# 6          NaN          NaN

# %%
center = [60.5790, 15.0652]
map = folium.Map(location=center, zoom_start=10)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_62ac1ea1f2964e919d0e479b86d8e4e4%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_62ac1ea1f2964e919d0e479b86d8e4e4%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_62ac1ea1f2964e919d0e479b86d8e4e4%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_62ac1ea1f2964e919d0e479b86d8e4e4%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B60.579%2C%2015.0652%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
for index, sensor in sensor.iterrows():
    location = [sensor['latitude'], sensor['longitude']]
    folium.Marker(location, popup = f'sensor_name:{sensor["sensor_name"]}\n app_id:{sensor["app_id"]}\n \
    install_time:{sensor["install_time"]}\n adress:{sensor["adress"]}\n \
    number:{sensor["number"]}\n zip_code:{sensor["zip_code"]}\n \
    city:{sensor["city"]}\n status:{sensor["status"]}\n activity:{sensor["activity"]}',icon=folium.Icon(icon="cloud")).add_to(map)

# save map to html file
# map.save('index.html')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_62ac1ea1f2964e919d0e479b86d8e4e4%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_62ac1ea1f2964e919d0e479b86d8e4e4%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_62ac1ea1f2964e919d0e479b86d8e4e4%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_62ac1ea1f2964e919d0e479b86d8e4e4%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B60.579%2C%2015.0652%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
map.save('index.html')

# %%
map1 = folium.Map(location=center, zoom_start=10)

# %%
kw = {"prefix": "fa", "color": "green", "icon": "arrow-up"}

# %%
sensor['latitude']
# Out:
# 0    60.5790
# 1    60.4886
# 2    60.4878
# 3    60.4877
# 4    60.4887
# 5    60.4888
# 6    60.4877
# Name: latitude, dtype: float64

# %%
angle = 45
icon = folium.Icon(angle=angle, **kw)
location0 = [sensor['latitude'][0], sensor['longitude'][0]]
folium.Marker(location0, popup = f'sensor_name:{sensor["sensor_name"][0]}\n app_id:{sensor["app_id"][0]}\n \
install_time:{sensor["install_time"][0]}\n adress:{sensor["adress"][0]}\n \
number:{sensor["number"][0]}\n zip_code:{sensor["zip_code"][0]}\n \
city:{sensor["city"][0]}\n status:{sensor["status"][0]}\n activity:{sensor["activity"][0]}',icon=icon, tooltip=str(angle)).add_to(map1)

location1 = [sensor['latitude'][1], sensor['longitude'][1]]
folium.Marker(location1, popup = f'sensor_name:{sensor["sensor_name"][1]}\n app_id:{sensor["app_id"][1]}\n \
install_time:{sensor["install_time"][1]}\n adress:{sensor["adress"][1]}\n \
number:{sensor["number"][1]}\n zip_code:{sensor["zip_code"][1]}\n \
city:{sensor["city"][1]}\n status:{sensor["status"][1]}\n activity:{sensor["activity"][1]}',icon=folium.Icon(color="green")).add_to(map1)

location2 = [sensor['latitude'][2], sensor['longitude'][2]]
folium.Marker(location2, popup = f'sensor_name:{sensor["sensor_name"][2]}\n app_id:{sensor["app_id"][2]}\n \
install_time:{sensor["install_time"][2]}\n adress:{sensor["adress"][2]}\n \
number:{sensor["number"][2]}\n zip_code:{sensor["zip_code"][2]}\n \
city:{sensor["city"][2]}\n status:{sensor["status"][2]}\n activity:{sensor["activity"][2]}',icon=folium.Icon(color="red", icon="info-sign")).add_to(map1)

location3 = [sensor['latitude'][3], sensor['longitude'][3]]
folium.Marker(location3, popup = f'sensor_name:{sensor["sensor_name"][3]}\n app_id:{sensor["app_id"][3]}\n \
install_time:{sensor["install_time"][3]}\n adress:{sensor["adress"][3]}\n \
number:{sensor["number"][3]}\n zip_code:{sensor["zip_code"][3]}\n \
city:{sensor["city"][3]}\n status:{sensor["status"][3]}\n activity:{sensor["activity"][3]}',icon=folium.Icon(color='red', icon='envelope')).add_to(map1)

angle = 90
icon = folium.Icon(angle=angle, **kw)
location4 = [sensor['latitude'][4], sensor['longitude'][4]]
folium.Marker(location4, popup = f'sensor_name:{sensor["sensor_name"][4]}\n app_id:{sensor["app_id"][4]}\n \
install_time:{sensor["install_time"][4]}\n adress:{sensor["adress"][4]}\n \
number:{sensor["number"][4]}\n zip_code:{sensor["zip_code"][4]}\n \
city:{sensor["city"][4]}\n status:{sensor["status"][4]}\n activity:{sensor["activity"][4]}',icon=icon, tooltip=str(angle)).add_to(map1)

angle = 180
icon = folium.Icon(angle=angle, **kw)
location5 = [sensor['latitude'][5], sensor['longitude'][5]]
folium.Marker(location5, popup = f'sensor_name:{sensor["sensor_name"][5]}\n app_id:{sensor["app_id"][5]}\n \
install_time:{sensor["install_time"][5]}\n adress:{sensor["adress"][5]}\n \
number:{sensor["number"][5]}\n zip_code:{sensor["zip_code"][5]}\n \
city:{sensor["city"][5]}\n status:{sensor["status"][5]}\n activity:{sensor["activity"][5]}',icon=icon, tooltip=str(angle)).add_to(map1)


location6 = [sensor['latitude'][6], sensor['longitude'][6]]
folium.Marker(location6, popup = f'sensor_name:{sensor["sensor_name"][6]}\n app_id:{sensor["app_id"][6]}\n \
install_time:{sensor["install_time"][6]}\n adress:{sensor["adress"][6]}\n \
number:{sensor["number"][6]}\n zip_code:{sensor["zip_code"][6]}\n \
city:{sensor["city"][6]}\n status:{sensor["status"][6]}\n activity:{sensor["activity"][6]}',icon=folium.Icon(icon="cloud")).add_to(map1)

map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_8987132b18a6497492182c33fd56de69%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_8987132b18a6497492182c33fd56de69%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_8987132b18a6497492182c33fd56de69%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_8987132b18a6497492182c33fd56de69%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B60.579%2C%2015.0652%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
response = requests.get("https://www.thethingsnetwork.org/gateway-data/location?latitude=60.48746&amp;longitude=15.409658&amp;distance=200000")
todos = json.loads(response.text)

# %%
todos
# Out:
# {'akersberga_1': {'id': 'akersberga_1',
#   'description': 'Things Network Gateway i Åkersberga, Runö Gård',
#   'owner': 'nicolas_innocenti',
#   'owners': ['nicolas_innocenti'],
#   'location': {'latitude': 59.48198465,
#    'longitude': 18.28747217,
#    'altitude': 15},
#   'country_code': 'se',
#   'attributes': {'antenna_model': 'The one included in the box',
#    'brand': 'The Things Products',
#    'frequency_plan': 'EU_863_870',
#    'model': 'The Things Gateway',
#    'placement': 'indoor',
#    'version': 'v1.0.8-846da98b'},
#   'last_seen': '2021-04-23T15:25:40Z'},
#  'bifrost': {'id': 'bifrost',
#   'location': {'latitude': 59.29041045,
#    'longitude': 17.9518368,
#    'altitude': 50},
#   'country_code': 'se',
#   'attributes': {'antenna_model': 'https://www.kjell.com/se/sortiment/dator-natverk/natverk/mobilt-bredband/antenn/4g-antenn/midimag-4g-antenn-7-8-dbi-p30064',
#    'brand': 'The Things Products',
#    'frequency_plan': 'EU_863_870',
#    'model': 'The Things Gateway',
#    'placement': 'outdoor',
#    'version': 'v1.0.8-846da98b'},
#   'last_seen': '2021-05-12T15:48:20Z'},
#  'dept-gw-2': {'id': 'dept-gw-2',
#   'location': {'latitude': 59.3101554,
#    'longitude': 18.00452202,
#    'altitude': 10},
#   'country_code': 'se',
#   'attributes': {'brand': 'The Things Products',
#    'frequency_plan': 'EU_863_870',
#    'model': 'The Things Gateway',
#    'placement': 'indoor',
#    'version': 'v1.0.8-846da98b'},
#   'last_seen': '2021-05-03T05:59:14Z'},
#  'enfo-orebro-1': {'id': 'enfo-orebro-1',
#   'description': 'ENFO Örebro',
#   'location': {'latitude': 59.27268801,
#    'longitude': 15.20946385,
#    'altitude': 10},
#   'country_code': 'se',
#   'attributes': {'brand': 'The Things Products',
#    'frequency_plan': 'EU_863_870',
#    'model': 'The Things Gateway',
#    'placement': 'indoor',
#    'version': 'v1.0.8-846da98b'},
#   'last_seen': '2021-05-12T15:48:16Z'},
#  'enfo-ttn-demo': {'id': 'enfo-ttn-demo',
#   'description': 'demo',
#   'location': {'latitude': 59.6114061,
#    'longitude': 16.54089276,
#    'altitude': 0},
#   'country_code': 'se',
#   'attributes': {'brand': 'Laird',
#    'frequency_plan': 'EU_863_870',
#    'model': 'Sentrius RG186',
#    'placement': 'indoor'},
#   'last_seen': '2021-05-04T07:08:54Z'},
#  'eui-000080029c10dc6e': {'id': 'eui-000080029c10dc6e',
#   'location': {'latitude': 60.4874382019043,
#    'longitude': 15.409658432006836,
#    'altitude': 147},
#   'country_code': 'se',
#   'attributes': {'brand': 'Gemtek', 'frequency_plan': 'EU_863_870'},
#   'last_seen': '2021-05-12T15:48:25Z'},
#  'eui-000080029c641ea2': {'id': 'eui-000080029c641ea2',
#   'description': 'Inter-Data',
#   'owner': 'jurian1980',
#   'owners': ['jurian1980'],
#   'location': {'latitude': 60.01525782,
#    'longitude': 13.73019416,
#    'altitude': 400},
#   'country_code': 'se',
#   'attributes': {'antenna_model': 'Sirio GP 868 C Polemount',
#    'brand': 'Gemtek',
#    'frequency_plan': 'EU_863_870',
#    'model': 'The Things Outdoor Gateway',
#    'placement': 'outdoor'},
#   'last_seen': '2021-05-12T15:48:08Z'},
#  'eui-3133303715002b00': {'id': 'eui-3133303715002b00',
#   'location': {'latitude': 59.273536682128906,
#    'longitude': 18.000097274780273,
#    'altitude': 35},
#   'country_code': 'se',
#   'attributes': {'frequency_plan': 'EU_863_870'},
#   'last_seen': '2021-04-14T18:05:36Z'},
#  'eui-3133303716002d00': {'id': 'eui-3133303716002d00',
#   'description': 'Provplats för MikroTik LR8',
#   'owner': 'wontolla',
#   'owners': ['wontolla'],
#   'location': {'latitude': 59.2968, 'longitude': 17.9682, 'altitude': 0},
#   'country_code': 'se',
#   'attributes': {'brand': 'MikroTik',
#    'frequency_plan': 'EU_863_870',
#    'model': 'LR8',
#    'placement': 'outdoor'},
#   'last_seen': '2021-05-12T15:48:31Z'},
#  'eui-3133303719004400': {'id': 'eui-3133303719004400',
#   'description': 'Gullvivsvägen 9 Vallentuna',
#   'owner': 'indoorhannes',
#   'owners': ['indoorhannes'],
#   'location': {'latitude': 59.54869853,
#    'longitude': 18.07458998,
#    'altitude': 0},
#   'country_code': 'se',
#   'attributes': {'frequency_plan': 'EU_863_870', 'placement': 'indoor'},
#   'last_seen': '2021-05-12T15:48:06Z'},
#  'eui-3133303719005000': {'id': 'eui-3133303719005000',
#   'description': 'Kontoret',
#   'owner': 'indoorhannes',
#   'owners': ['indoorhannes'],
#   'location': {'latitude': 59.35578049,
#    'longitude': 17.97452436,
#    'altitude': 0},
#   'country_code': 'se',
#   'attributes': {'frequency_plan': 'EU_863_870', 'placement': 'indoor'},
#   'last_seen': '2021-05-12T15:48:25Z'},
#  'eui-313330371a005f00': {'id': 'eui-313330371a005f00',
#   'description': 'ttn-taby-mikrotik',
#   'owner': 'grobius',
#   'owners': ['grobius'],
#   'location': {'latitude': 59.42375345,
#    'longitude': 18.09997886,
#    'altitude': 0},
#   'country_code': 'se',
#   'attributes': {'antenna_model': 'Mikrotik 6.5 dBi Omni antenna',
#    'brand': 'Mikrotik',
#    'frequency_plan': 'EU_863_870',
#    'model': 'wAP LR8',
#    'placement': 'outdoor'},
#   'last_seen': '2021-05-12T15:48:28Z'},
#  'eui-313532354a006700': {'id': 'eui-313532354a006700',
#   'description': 'AxByte Älvsjö',
#   'owner': 'axbyte',
#   'owners': ['axbyte'],
#   'location': {'latitude': 59.27152321,
#    'longitude': 18.0067497,
#    'altitude': 53},
#   'country_code': 'se',
#   'attributes': {'antenna_model': 'MikroTik LoRa 6.5 dBi antenna kit',
#    'brand': 'MikroTik',
#    'frequency_plan': 'EU_863_870',
#    'model': 'wAP LoRa8 kit',
#    'placement': 'outdoor'},
#   'last_seen': '2021-05-12T15:48:34Z'},
#  'eui-323531322f002500': {'id': 'eui-323531322f002500',
#   'description': 'Skanstull',
#   'owner': 'mala57',
#   'owners': ['mala57'],
#   'location': {'latitude': 59.30704987,
#    'longitude': 18.08055997,
#    'altitude': 30},
#   'country_code': 'se',
#   'attributes': {'frequency_plan': 'EU_863_870', 'placement': 'outdoor'},
#   'last_seen': '2021-05-12T01:18:56Z'},
#  'eui-333833301c004a00': {'id': 'eui-333833301c004a00',
#   'description': 'inedal',
#   'owner': 'inedal',
#   'owners': ['inedal'],
#   'location': {'latitude': 59.33490309,
#    'longitude': 18.0349258,
#    'altitude': 12},
#   'country_code': 'se',
#   'attributes': {'brand': 'n-Fuse',
#    'frequency_plan': 'EU_863_870',
#    'model': 'Raspberry Pi based LRWGWX',
#    'placement': 'outdoor'},
#   'last_seen': '2021-05-12T15:48:19Z'},
#  'eui-3338333029002400': {'id': 'eui-3338333029002400',
#   'description': 'Hjortywood Heights - TestGW2',
#   'owner': 'molex',
#   'owners': ['molex'],
#   'location': {'latitude': 59.35481619,
#    'longitude': 18.09437699,
#    'altitude': 0},
#   'country_code': 'se',
#   'attributes': {'antenna_model': 'Aurel GP',
#    'brand': 'Raspberry Pi based',
#    'frequency_plan': 'EU_863_870',
#    'model': 'LRWCCx',
#    'placement': 'indoor'},
#   'last_seen': '2021-05-12T15:48:32Z'},
#  'eui-40d63cfffe027dfe': {'id': 'eui-40d63cfffe027dfe',
#   'description': 'bandhagen',
#   'owner': 'debugger',
#   'owners': ['debugger'],
#   'location': {'latitude': 59.27099952,
#    'longitude': 18.04779088,
#    'altitude': 45},
#   'country_code': 'se',
#   'attributes': {'antenna_model': 'Mounted on top (3rd) floor balcony facing East',
#    'brand': 'MatchX',
#    'frequency_plan': 'EU_863_870',
#    'model': 'Box MX1701',
#    'placement': 'outdoor'},
#   'last_seen': '2021-05-03T05:56:40Z'},
#  'eui-58a0cbfffe800cce': {'id': 'eui-58a0cbfffe800cce',
#   'description': 'The Things Indoor Gateway 1',
#   'owner': 'emiljaregran',
#   'owners': ['emiljaregran'],
#   'location': {'latitude': 59.88819777,
#    'longitude': 17.64934986,
#    'altitude': 32},
#   'country_code': 'se',
#   'attributes': {'antenna_model': 'PCB antenna',
#    'brand': 'The Things Industries',
#    'frequency_plan': 'EU_863_870',
#    'model': 'The Things Indoor Gateway',
#    'placement': 'indoor',
#    'version': '2.0.0'},
#   'last_seen': '2021-05-12T15:47:03Z'},
#  'eui-58a0cbfffe800e5b': {'id': 'eui-58a0cbfffe800e5b',
#   'description': 'minihub 1',
#   'owner': 'grovkillen',
#   'owners': ['grovkillen'],
#   'location': {'latitude': 61.77352571,
#    'longitude': 17.01261644,
#    'altitude': 32},
#   'country_code': 'se',
#   'attributes': {'brand': 'The Things Industries',
#    'frequency_plan': 'EU_863_870',
#    'model': 'The Things Indoor Gateway',
#    'placement': 'indoor',
#    'version': '2.0.0'},
#   'last_seen': '2021-05-12T09:04:37Z'},
#  'eui-58a0cbfffe801a32': {'id': 'eui-58a0cbfffe801a32',
#   'description': 'Brunnsberg',
#   'owner': 'pebry',
#   'owners': ['pebry'],
#   'location': {'latitude': 61.28402805,
#    'longitude': 13.9236635,
#    'altitude': 5},
#   'country_code': 'se',
#   'attributes': {'antenna_model': 'Internal',
#    'brand': 'The Things Industries',
#    'frequency_plan': 'EU_863_870',
#    'model': 'The Things Indoor Gateway',
#    'placement': 'indoor',
#    'version': '2.0.0'},
#   'last_seen': '2021-05-12T15:47:32Z'},
#  'eui-58a0cbfffe801dd0': {'id': 'eui-58a0cbfffe801dd0',
#   'description': 'SpeedApp AB',
#   'location': {'latitude': 59.63275378,
#    'longitude': 16.54850642,
#    'altitude': 0},
#   'country_code': 'se',
#   'attributes': {'brand': 'The Things Industries',
#    'frequency_plan': 'EU_863_870',
#    'model': 'The Things Indoor Gateway',
#    'placement': 'indoor',
#    'version': '2.0.0'},
#   'last_seen': '2021-04-21T23:03:01Z'},
#  'eui-58a0cbfffe802190': {'id': 'eui-58a0cbfffe802190',
#   'description': 'Spetby skola',
#   'owner': 'spetbyskola',
#   'owners': ['spetbyskola'],
#   'location': {'latitude': 59.21312771,
#    'longitude': 16.22137978,
#    'altitude': 55},
#   'country_code': 'se',
#   'attributes': {'antenna_model': 'Built in',
#    'brand': 'The Things Industries',
#    'frequency_plan': 'EU_863_870',
#    'model': 'The Things Indoor Gateway',
#    'placement': 'indoor',
#    'version': '2.0.0'},
#   'last_seen': '2021-05-12T15:06:25Z'},
#  'eui-58a0cbfffe802a9d': {'id': 'eui-58a0cbfffe802a9d',
#   'description': 'Eklosa gw',
#   'owner': 'gorhoi',
#   'owners': ['gorhoi'],
#   'location': {'latitude': 59.63832823,
#    'longitude': 18.23493513,
#    'altitude': 0},
#   'country_code': 'se',
#   'attributes': {'brand': 'The Things Industries',
#    'frequency_plan': 'EU_863_870',
#    'model': 'The Things Indoor Gateway',
#    'placement': 'indoor',
#    'version': '2.0.0'},
#   'last_seen': '2021-05-12T15:30:28Z'},
#  'eui-60c5a8fffe71d210': {'id': 'eui-60c5a8fffe71d210',
#   'description': '60C5A8FFFE71D210 Sweden Demo Kista 915',
#   'location': {'latitude': 59.40537726,
#    'longitude': 17.94574503,
#    'altitude': 0},
#   'country_code': 'se',
#   'attributes': {'brand': 'Tannak International',
#    'frequency_plan': 'US_902_928',
#    'model': 'TLBS-01-4G',
#    'placement': 'outdoor'}},
#  'eui-60c5a8fffe71d212': {'id': 'eui-60c5a8fffe71d212',
#   'description': '60C5A8FFFE71D212 Sweden Demo Kista 868',
#   'location': {'latitude': 59.40534826,
#    'longitude': 17.94573655,
#    'altitude': 7},
#   'country_code': 'se',
#   'attributes': {'brand': 'VestiTech',
#    'frequency_plan': 'EU_863_870',
#    'placement': 'indoor'},
#   'last_seen': '2021-05-12T15:48:11Z'},
#  'eui-60c5a8fffe7614f0': {'id': 'eui-60c5a8fffe7614f0',
#   'description': 'Senseair RAK01',
#   'owner': 'senseair',
#   'owners': ['senseair'],
#   'location': {'latitude': 61.79646302,
#    'longitude': 16.55854927,
#    'altitude': 0},
#   'country_code': 'se',
#   'attributes': {'brand': 'RAKwireless',
#    'frequency_plan': 'EU_863_870',
#    'model': 'linux - Firmware  - Protocol 2',
#    'placement': 'outdoor'},
#   'last_seen': '2021-04-30T14:45:39Z'},
#  'eui-60c5a8fffe783d85': {'id': 'eui-60c5a8fffe783d85',
#   'description': 'RAK7258 Gateway',
#   'owner': 'things_abasto',
#   'owners': ['things_abasto'],
#   'location': {'latitude': 59.63891587,
#    'longitude': 17.7619614,
#    'altitude': 0},
#   'country_code': 'se',
#   'attributes': {'brand': 'RAKwireless',
#    'frequency_plan': 'EU_863_870',
#    'model': '7258',
#    'placement': 'indoor'},
#   'last_seen': '2021-05-12T15:48:24Z'},
#  'eui-a840411d23b44150': {'id': 'eui-a840411d23b44150',
#   'description': 'Dragino_Home',
#   'owner': 'trinsic',
#   'owners': ['trinsic'],
#   'location': {'latitude': 59.44103303,
#    'longitude': 13.42785935,
#    'altitude': 0},
#   'country_code': 'se',
#   'attributes': {'brand': 'Dragino',
#    'frequency_plan': 'EU_863_870',
#    'placement': 'indoor'},
#   'last_seen': '2021-05-12T15:48:13Z'},
#  'eui-a840411daea84150': {'id': 'eui-a840411daea84150',
#   'location': {'latitude': 60.6546516418457,
#    'longitude': 17.159639358520508,
#    'altitude': 0},
#   'country_code': 'se',
#   'attributes': {'brand': 'Dragino', 'frequency_plan': 'US_902_928'},
#   'last_seen': '2021-05-03T11:51:07Z'},
#  'eui-a840411daf784150': {'id': 'eui-a840411daf784150',
#   'description': 'LG02-Gateway-1',
#   'owner': 'marshall-9914-20',
#   'owners': ['marshall-9914-20'],
#   'location': {'latitude': 61.41132304,
#    'longitude': 16.65731607,
#    'altitude': 0},
#   'country_code': 'se',
#   'attributes': {'brand': 'Dragino', 'frequency_plan': 'EU_863_870'},
#   'last_seen': '2021-05-12T15:48:18Z'},
#  'eui-a840411dbca84150': {'id': 'eui-a840411dbca84150',
#   'description': 'jornik-gw-2',
#   'owner': 'jornik',
#   'owners': ['jornik'],
#   'location': {'latitude': 59.42996751,
#    'longitude': 18.04306472,
#    'altitude': 0},
#   'country_code': 'se',
#   'attributes': {'brand': 'Dragino', 'frequency_plan': 'EU_863_870'},
#   'last_seen': '2021-05-12T15:48:18Z'},
#  'eui-a840411e9a1c4150': {'id': 'eui-a840411e9a1c4150',
#   'description': 'EffarGW',
#   'location': {'latitude': 59.4527611,
#    'longitude': 17.98044405,
#    'altitude': 24},
#   'country_code': 'se',
#   'attributes': {'brand': 'Dragino',
#    'frequency_plan': 'EU_863_870',
#    'model': 'LPS8',
#    'placement': 'indoor'},
#   'last_seen': '2021-05-12T15:48:06Z'},
#  'eui-a840411ec2044150': {'id': 'eui-a840411ec2044150',
#   'description': 'Dragino LPS8 Homegateway for developement',
#   'owner': 'jsandberg',
#   'owners': ['jsandberg'],
#   'location': {'latitude': 59.6083781,
#    'longitude': 17.47524846,
#    'altitude': 0},
#   'country_code': 'se',
#   'attributes': {'brand': 'Dragino',
#    'frequency_plan': 'EU_863_870',
#    'model': 'LPS8'},
#   'last_seen': '2021-04-17T17:03:55Z'},
#  'eui-ac1f09fffe004f22': {'id': 'eui-ac1f09fffe004f22',
#   'description': 'RAK7249 no 2',
#   'owner': 'grovkillen',
#   'owners': ['grovkillen'],
#   'location': {'latitude': 61.77350302,
#    'longitude': 17.0126401,
#    'altitude': 45},
#   'country_code': 'se',
#   'attributes': {'antenna_model': 'Fiberglass',
#    'brand': 'RAKwireless',
#    'frequency_plan': 'EU_863_870',
#    'model': '7249',
#    'placement': 'outdoor'},
#   'last_seen': '2021-05-12T15:48:06Z'},
#  'eui-b827ebfffe1749b6': {'id': 'eui-b827ebfffe1749b6',
#   'description': 'Henriksdalsberget',
#   'owner': 'simply',
#   'owners': ['simply'],
#   'location': {'latitude': 59.309922, 'longitude': 18.113887, 'altitude': 60},
#   'country_code': 'se',
#   'attributes': {'antenna_model': 'GP',
#    'brand': 'Raspberry Pi based',
#    'frequency_plan': 'EU_863_870',
#    'model': 'RAK831',
#    'placement': 'outdoor'},
#   'last_seen': '2021-05-12T15:48:35Z'},
#  'eui-b827ebfffe6803c1': {'id': 'eui-b827ebfffe6803c1',
#   'description': 'My home experiment gateway',
#   'owner': 'sm0rvv',
#   'owners': ['sm0rvv'],
#   'location': {'latitude': 59.39963107,
#    'longitude': 17.87000987,
#    'altitude': 3},
#   'country_code': 'se',
#   'attributes': {'antenna_model': '1/4 wave',
#    'brand': 'Raspberry Pi based',
#    'frequency_plan': 'EU_863_870',
#    'model': 'RAK831',
#    'placement': 'indoor'},
#   'last_seen': '2021-05-12T15:48:23Z'},
#  'eui-b827ebfffe7d517d': {'id': 'eui-b827ebfffe7d517d',
#   'description': 'PI-ttn-ic880a',
#   'owner': 'mstjerna',
#   'owners': ['mstjerna'],
#   'location': {'latitude': 59.238255, 'longitude': 17.965618, 'altitude': 0},
#   'country_code': 'se',
#   'attributes': {'brand': 'Raspberry Pi based',
#    'frequency_plan': 'EU_863_870',
#    'placement': 'indoor'},
#   'last_seen': '2021-05-12T15:48:24Z'},
#  'eui-b827ebfffeb6aad1': {'id': 'eui-b827ebfffeb6aad1',
#   'description': 'RPI+RAK2245',
#   'location': {'latitude': 59.41129549,
#    'longitude': 13.51004899,
#    'altitude': 55},
#   'country_code': 'se',
#   'attributes': {'antenna_model': '1/2 wave',
#    'brand': 'Raspberry Pi based',
#    'frequency_plan': 'EU_863_870',
#    'model': 'RAK2245',
#    'placement': 'indoor'},
#   'last_seen': '2021-04-22T16:13:13Z'},
#  'eui-b827ebfffebbf8bb': {'id': 'eui-b827ebfffebbf8bb',
#   'description': 'Stuvaregatan Gavle Sweden',
#   'owner': 'slaskhas',
#   'owners': ['slaskhas'],
#   'location': {'latitude': 60.67985331,
#    'longitude': 17.1699362,
#    'altitude': 3},
#   'country_code': 'se',
#   'attributes': {'brand': 'Raspberry Pi based',
#    'frequency_plan': 'EU_863_870',
#    'model': 'IMST',
#    'placement': 'indoor'},
#   'last_seen': '2021-05-12T15:48:30Z'},
#  'eui-b827ebfffedb2680': {'id': 'eui-b827ebfffedb2680',
#   'description': 'CE-GW001',
#   'location': {'latitude': 59.37398787,
#    'longitude': 18.01080287,
#    'altitude': 24},
#   'country_code': 'se',
#   'attributes': {'brand': 'Raspberry Pi based',
#    'frequency_plan': 'EU_863_870',
#    'model': 'RAK831',
#    'placement': 'indoor'},
#   'last_seen': '2021-05-12T15:48:20Z'},
#  'eui-b827ebfffedf20e3': {'id': 'eui-b827ebfffedf20e3',
#   'description': 'Tranholmen',
#   'owner': 'mellbratt',
#   'owners': ['mellbratt'],
#   'location': {'latitude': 59.375396239550696,
#    'longitude': 18.08698163585666,
#    'altitude': 30},
#   'country_code': 'se',
#   'attributes': {'antenna_model': 'Taoglas OMB',
#    'brand': 'Raspberry Pi based',
#    'frequency_plan': 'EU_863_870',
#    'model': 'IMST',
#    'placement': 'indoor'},
#   'last_seen': '2021-05-12T15:48:10Z'},
#  'eui-b827ebffff95ea42': {'id': 'eui-b827ebffff95ea42',
#   'description': 'Jakobsberg single frequency gateway',
#   'owner': 'andy1551',
#   'owners': ['andy1551'],
#   'location': {'latitude': 59.42916919,
#    'longitude': 17.82482319,
#    'altitude': 40},
#   'country_code': 'se',
#   'attributes': {'antenna_model': 'lambda/4 Ground Plane',
#    'brand': 'Raspberry Pi based',
#    'frequency_plan': 'EU_863_870',
#    'model': 'Pi3 with Dragino shield, 868.1 MHz, SF12',
#    'placement': 'indoor'},
#   'last_seen': '2021-05-12T15:48:28Z'},
#  'eui-c0ee40ffff29356b': {'id': 'eui-c0ee40ffff29356b',
#   'description': 'KELLER Laird LoRa Gateway @Keller Sweden',
#   'owner': 'kellersweden',
#   'owners': ['kellersweden'],
#   'location': {'latitude': 59.95414039,
#    'longitude': 17.54236304,
#    'altitude': 4},
#   'country_code': 'se',
#   'attributes': {'antenna_model': 'Aurel GP',
#    'brand': 'Laird',
#    'frequency_plan': 'EU_863_870',
#    'model': 'Sentrius RG1xx',
#    'placement': 'indoor'},
#   'last_seen': '2021-05-12T15:48:29Z'},
#  'eui-c0ee40ffff2976d7': {'id': 'eui-c0ee40ffff2976d7',
#   'description': 'Växtväggsövervakning',
#   'owner': 'greenworks',
#   'owners': ['greenworks'],
#   'location': {'latitude': 59.31161534,
#    'longitude': 18.07602614,
#    'altitude': 0},
#   'country_code': 'se',
#   'attributes': {'brand': 'Laird',
#    'frequency_plan': 'EU_863_870',
#    'placement': 'indoor'},
#   'last_seen': '2021-04-15T04:15:43Z'},
#  'eui-c82319faab120912': {'id': 'eui-c82319faab120912',
#   'description': 'ABGw',
#   'owner': 'andreasbergkvist',
#   'owners': ['andreasbergkvist'],
#   'location': {'latitude': 60.60981727,
#    'longitude': 15.62370892,
#    'altitude': 0},
#   'country_code': 'se',
#   'attributes': {'frequency_plan': 'EU_863_870', 'placement': 'indoor'},
#   'last_seen': '2021-05-12T15:47:32Z'},
#  'eui-dca632fffe6aad50': {'id': 'eui-dca632fffe6aad50',
#   'description': 'Odenslätt GW',
#   'owner': 'hasse1989',
#   'owners': ['hasse1989'],
#   'location': {'latitude': 60.38985191,
#    'longitude': 17.4211827,
#    'altitude': 0},
#   'country_code': 'se',
#   'attributes': {'antenna_model': '5 db Fiber',
#    'brand': 'RAKwireless',
#    'frequency_plan': 'EU_863_870',
#    'model': '7244p',
#    'placement': 'outdoor'},
#   'last_seen': '2021-05-12T15:48:17Z'},
#  'eui-fcc23dfffe206746': {'id': 'eui-fcc23dfffe206746',
#   'description': 'Lorix-Färingsö',
#   'location': {'latitude': 59.41790468,
#    'longitude': 17.66293552,
#    'altitude': 10},
#   'country_code': 'se',
#   'attributes': {'antenna_model': 'Procom CXL 900-3LW-NB',
#    'brand': 'Lorix',
#    'frequency_plan': 'EU_863_870',
#    'model': 'One',
#    'placement': 'outdoor'},
#   'last_seen': '2021-05-12T15:48:32Z'},
#  'eui-fcc23dfffe209fa2': {'id': 'eui-fcc23dfffe209fa2',
#   'description': 'SLU-Siljansfors3 (LorixOne)',
#   'owner': 'olalangvall',
#   'owners': ['olalangvall'],
#   'location': {'latitude': 60.89220185,
#    'longitude': 14.37481712,
#    'altitude': 0},
#   'country_code': 'se',
#   'attributes': {'frequency_plan': 'EU_863_870', 'placement': 'outdoor'},
#   'last_seen': '2021-05-12T15:48:35Z'},
#  'eui-fcc23dfffe20ded8': {'id': 'eui-fcc23dfffe20ded8',
#   'description': 'SLU-Siljansfors2 (LorixOne)',
#   'owner': 'olalangvall',
#   'owners': ['olalangvall'],
#   'location': {'latitude': 60.88072853,
#    'longitude': 14.38528352,
#    'altitude': 0},
#   'country_code': 'se',
#   'attributes': {'frequency_plan': 'EU_863_870', 'placement': 'outdoor'},
#   'last_seen': '2021-05-12T15:48:35Z'},
#  'loragw1_limetransit_com': {'id': 'loragw1_limetransit_com',
#   'description': 'loragw1.limetransit.com',
#   'owner': 'sverker',
#   'owners': ['sverker'],
#   'location': {'latitude': 59.35926447,
#    'longitude': 18.0003232,
#    'altitude': 15},
#   'country_code': 'se',
#   'attributes': {'brand': 'Raspberry Pi based',
#    'frequency_plan': 'EU_863_870',
#    'model': 'PiSupply',
#    'placement': 'indoor'},
#   'last_seen': '2021-05-12T15:48:33Z'},
#  'modigdesign': {'id': 'modigdesign',
#   'description': 'Modig Design Development Gateway',
#   'owner': 'ulfmodig',
#   'owners': ['ulfmodig'],
#   'location': {'latitude': 59.3708158,
#    'longitude': 17.20866635,
#    'altitude': 0},
#   'attributes': {'antenna_model': 'DeLock 89583',
#    'brand': 'Raspberry Pi based',
#    'frequency_plan': 'EU_863_870',
#    'model': 'PiSupply',
#    'placement': 'outdoor'},
#   'last_seen': '2021-05-12T15:48:31Z'},
#  'rg1xx293bf9': {'id': 'rg1xx293bf9',
#   'description': 'Addiva Lora',
#   'owner': 'einarmattsonpilot',
#   'owners': ['einarmattsonpilot'],
#   'location': {'latitude': 59.60596856,
#    'longitude': 16.55294575,
#    'altitude': 0},
#   'country_code': 'se',
#   'attributes': {'brand': 'Laird',
#    'frequency_plan': 'EU_863_870',
#    'model': 'Sentrius RG186',
#    'placement': 'indoor'},
#   'last_seen': '2021-05-12T15:48:34Z'},
#  'sa_lora01': {'id': 'sa_lora01',
#   'description': 'Senseair AB_01',
#   'owner': 'senseair',
#   'owners': ['senseair'],
#   'location': {'latitude': 61.70998317,
#    'longitude': 16.63796251,
#    'altitude': 110},
#   'country_code': 'se',
#   'attributes': {'antenna_model': 'Aurel GP',
#    'brand': 'The Things Products',
#    'frequency_plan': 'EU_863_870',
#    'model': 'The Things Gateway',
#    'placement': 'indoor',
#    'version': 'v1.0.8-846da98b'},
#   'last_seen': '2021-05-12T15:48:35Z'},
#  'se-sto-bbt01': {'id': 'se-sto-bbt01',
#   'description': 'Pi Supply GW',
#   'owner': 'foo8ar',
#   'owners': ['foo8ar'],
#   'location': {'latitude': 59.52188, 'longitude': 17.848204, 'altitude': 19},
#   'country_code': 'se',
#   'attributes': {'brand': 'Raspberry Pi based',
#    'frequency_plan': 'EU_863_870',
#    'model': 'PiSupply',
#    'placement': 'outdoor'},
#   'last_seen': '2021-05-12T15:48:24Z'},
#  'strucknet01': {'id': 'strucknet01',
#   'owner': 'strucknet',
#   'owners': ['strucknet'],
#   'location': {'latitude': 59.39828926,
#    'longitude': 17.89548336,
#    'altitude': 0},
#   'country_code': 'se',
#   'attributes': {'brand': 'The Things Products',
#    'frequency_plan': 'EU_863_870',
#    'model': 'The Things Gateway',
#    'placement': 'indoor',
#    'version': 'v1.0.8-846da98b'},
#   'last_seen': '2021-05-12T15:48:36Z'},
#  'tbg-ttn-gw-1': {'id': 'tbg-ttn-gw-1',
#   'description': 'tbg-ttn-gw-1',
#   'owner': 'mist',
#   'owners': ['mist'],
#   'location': {'latitude': 59.4819448,
#    'longitude': 17.9251273,
#    'altitude': 26},
#   'country_code': 'se',
#   'attributes': {'brand': 'Raspberry Pi based',
#    'frequency_plan': 'EU_863_870',
#    'model': 'IMST',
#    'placement': 'indoor'},
#   'last_seen': '2021-05-12T15:48:08Z'}}

# %%
type(todos)
# Out:
# dict

# %%
todosd = pd.DataFrame.from_dict(todos, orient='index')

# %%
todosd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56 entries, akersberga_1 to tbg-ttn-gw-1
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            56 non-null     object
#  1   description   50 non-null     object
#  2   owner         42 non-null     object
#  3   owners        42 non-null     object
#  4   location      56 non-null     object
#  5   country_code  55 non-null     object
#  6   attributes    56 non-null     object
#  7   last_seen     55 non-null     object
# dtypes: object(8)
# memory usage: 3.9+ KB

# %%
todosd=pd.concat([todosd.drop(['location'], axis=1), todosd['location'].apply(pd.Series)],axis=1)
todosd=pd.concat([todosd.drop(['attributes'], axis=1), todosd['attributes'].apply(pd.Series)],axis=1)

# %%
todosd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56 entries, akersberga_1 to tbg-ttn-gw-1
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              56 non-null     object
#  1   description     50 non-null     object
#  2   owner           42 non-null     object
#  3   owners          42 non-null     object
#  4   country_code    55 non-null     object
#  5   last_seen       55 non-null     object
#  6   latitude        56 non-null     float64
#  7   longitude       56 non-null     float64
#  8   altitude        56 non-null     float64
#  9   antenna_model   21 non-null     object
#  10  brand           49 non-null     object
#  11  frequency_plan  56 non-null     object
#  12  model           41 non-null     object
#  13  placement       50 non-null     object
#  14  version         12 non-null     object
# dtypes: float64(3), object(12)
# memory usage: 7.0+ KB

# %%
for index, todosd in todosd.iterrows():
    location = [todosd['latitude'], todosd['longitude']]
    folium.Marker(location, popup = f'id:{todosd["id"]}\n description:{todosd["description"]}\n \
    owner:{todosd["owner"]}\n owners:{todosd["owners"]}\n \
    country_code:{todosd["country_code"]}\n last_seen:{todosd["last_seen"]}\n \
    antenna_model:{todosd["antenna_model"]}\n brand :{todosd["brand"]}\n frequency_plan:{todosd["frequency_plan"]}\n \
    model:{todosd["model"]}\n placement:{todosd["placement"]}\n version:{todosd["version"]}',icon=folium.Icon(color="red")).add_to(map)
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_62ac1ea1f2964e919d0e479b86d8e4e4%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_62ac1ea1f2964e919d0e479b86d8e4e4%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_62ac1ea1f2964e919d0e479b86d8e4e4%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_62ac1ea1f2964e919d0e479b86d8e4e4%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B60.579%2C%2015.0652%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
legend_html = """
{% macro html(this, kwargs) %}
<div style="
    position: fixed;
    bottom: 50px;
    left: 50px;
    width: 250px;
    height: 150px;
    z-index:9999;
    font-size:14px;
    ">
    <p><strong>Legend</strong></p>
    <p><a style="color:#e6194b;font-size:150%;margin-left:20px;"></a>From CSV File</p>
    <p><a style="color:#19e6b4;font-size:150%;margin-left:20px;"></a>From API Calling</p>
</div>
<div style="
    position: fixed;
    bottom: 50px;
    left: 50px;
    width: 150px;
    height: 80px;
    z-index:9998;
    font-size:14px;
    background-color: #ffffff;
    filter: blur(8px);
    -webkit-filter: blur(8px);
    opacity: 0.7;
    ">
</div>
{% endmacro %}
"""

# %%
legend_html = """
{% macro html(this, kwargs) %}
<div style="
    position: fixed;
    bottom: 50px;
    left: 50px;
    width: 200px;
    height: 150px;
    z-index:9999;
    font-size:14px;
    border: 2px solid black;
    ">
    <p><a style="color:#e6194b;font-size:150%;margin-left:20px;"></a><strong>Legend</strong></p>
    <p><a style="color:#e6194b;font-size:150%;margin-left:20px;"></a><strong>From CSV File</strong></p>
    <p><a style="color:#19e6b4;font-size:150%;margin-left:20px;"></a><strong>From API Calling</strong></p>
</div>
<div style="
    position: fixed;
    bottom: 10px;
    left: 50px;
    width: 150px;
    height: 150px;
    z-index:9998;
    font-size:14px;
    ">
</div>
{% endmacro %}
"""

legend = branca.element.MacroElement()
legend._template = branca.element.Template(legend_html)

# %%
center = [60.5790, 15.0652]
map = folium.Map(location=center, zoom_start=10)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_5d7dd427bee84426bb6804e7caca34d6%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_5d7dd427bee84426bb6804e7caca34d6%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_5d7dd427bee84426bb6804e7caca34d6%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_5d7dd427bee84426bb6804e7caca34d6%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B60.579%2C%2015.0652%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
map.get_root().add_child(legend)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_5d7dd427bee84426bb6804e7caca34d6%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_5d7dd427bee84426bb6804e7caca34d6%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%0A%3Cdiv%20style%3D%22%0A%20%20%20%20position%3A%20fixed%3B%0A%20%20%20%20bottom%3A%2050px%3B%0A%20%20%20%20left%3A%2050px%3B%0A%20%20%20%20width%3A%20200px%3B%0A%20%20%20%20height%3A%20150px%3B%0A%20%20%20%20z-index%3A9999%3B%0A%20%20%20%20font-size%3A14px%3B%0A%20%20%20%20border%3A%202px%20solid%20black%3B%0A%20%20%20%20%22%3E%0A%20%20%20%20%3Cp%3E%3Ca%20style%3D%22color%3A%23e6194b%3Bfont-size%3A150%25%3Bmargin-left%3A20px%3B%22%3E%3C/a%3E%3Cst ...

# %%
temp = [(k, v) for k, v in dict.items()]

# %%
temp
# Out:
# [('akersberga_1',
#   {'id': 'akersberga_1',
#    'description': 'Things Network Gateway i Åkersberga, Runö Gård',
#    'owner': 'nicolas_innocenti',
#    'owners': ['nicolas_innocenti'],
#    'location': {'latitude': 59.48198465,
#     'longitude': 18.28747217,
#     'altitude': 15},
#    'country_code': 'se',
#    'attributes': {'antenna_model': 'The one included in the box',
#     'brand': 'The Things Products',
#     'frequency_plan': 'EU_863_870',
#     'model': 'The Things Gateway',
#     'placement': 'indoor',
#     'version': 'v1.0.8-846da98b'},
#    'last_seen': '2021-04-23T15:25:40Z'}),
#  ('bifrost',
#   {'id': 'bifrost',
#    'location': {'latitude': 59.29041045,
#     'longitude': 17.9518368,
#     'altitude': 50},
#    'country_code': 'se',
#    'attributes': {'antenna_model': 'https://www.kjell.com/se/sortiment/dator-natverk/natverk/mobilt-bredband/antenn/4g-antenn/midimag-4g-antenn-7-8-dbi-p30064',
#     'brand': 'The Things Products',
#     'frequency_plan': 'EU_863_870',
#     'model': 'The Things Gateway',
#     'placement': 'outdoor',
#     'version': 'v1.0.8-846da98b'},
#    'last_seen': '2021-05-12T08:25:43Z'}),
#  ('dept-gw-2',
#   {'id': 'dept-gw-2',
#    'location': {'latitude': 59.3101554,
#     'longitude': 18.00452202,
#     'altitude': 10},
#    'country_code': 'se',
#    'attributes': {'brand': 'The Things Products',
#     'frequency_plan': 'EU_863_870',
#     'model': 'The Things Gateway',
#     'placement': 'indoor',
#     'version': 'v1.0.8-846da98b'},
#    'last_seen': '2021-05-03T05:59:14Z'}),
#  ('enfo-orebro-1',
#   {'id': 'enfo-orebro-1',
#    'description': 'ENFO Örebro',
#    'location': {'latitude': 59.27268801,
#     'longitude': 15.20946385,
#     'altitude': 10},
#    'country_code': 'se',
#    'attributes': {'brand': 'The Things Products',
#     'frequency_plan': 'EU_863_870',
#     'model': 'The Things Gateway',
#     'placement': 'indoor',
#     'version': 'v1.0.8-846da98b'},
#    'last_seen': '2021-05-12T08:26:16Z'}),
#  ('enfo-ttn-demo',
#   {'id': 'enfo-ttn-demo',
#    'description': 'demo',
#    'location': {'latitude': 59.6114061,
#     'longitude': 16.54089276,
#     'altitude': 0},
#    'country_code': 'se',
#    'attributes': {'brand': 'Laird',
#     'frequency_plan': 'EU_863_870',
#     'model': 'Sentrius RG186',
#     'placement': 'indoor'},
#    'last_seen': '2021-05-04T07:08:54Z'}),
#  ('eui-000080029c10dc6e',
#   {'id': 'eui-000080029c10dc6e',
#    'location': {'latitude': 60.48746109008789,
#     'longitude': 15.409642219543457,
#     'altitude': 148},
#    'country_code': 'se',
#    'attributes': {'brand': 'Gemtek', 'frequency_plan': 'EU_863_870'},
#    'last_seen': '2021-05-12T08:26:13Z'}),
#  ('eui-000080029c641ea2',
#   {'id': 'eui-000080029c641ea2',
#    'description': 'Inter-Data',
#    'owner': 'jurian1980',
#    'owners': ['jurian1980'],
#    'location': {'latitude': 60.01525782,
#     'longitude': 13.73019416,
#     'altitude': 400},
#    'country_code': 'se',
#    'attributes': {'antenna_model': 'Sirio GP 868 C Polemount',
#     'brand': 'Gemtek',
#     'frequency_plan': 'EU_863_870',
#     'model': 'The Things Outdoor Gateway',
#     'placement': 'outdoor'},
#    'last_seen': '2021-05-12T08:26:07Z'}),
#  ('eui-3133303715002b00',
#   {'id': 'eui-3133303715002b00',
#    'location': {'latitude': 59.273536682128906,
#     'longitude': 18.000097274780273,
#     'altitude': 35},
#    'country_code': 'se',
#    'attributes': {'frequency_plan': 'EU_863_870'},
#    'last_seen': '2021-04-14T18:05:36Z'}),
#  ('eui-3133303716002d00',
#   {'id': 'eui-3133303716002d00',
#    'description': 'Provplats för MikroTik LR8',
#    'owner': 'wontolla',
#    'owners': ['wontolla'],
#    'location': {'latitude': 59.2968, 'longitude': 17.9682, 'altitude': 0},
#    'country_code': 'se',
#    'attributes': {'brand': 'MikroTik',
#     'frequency_plan': 'EU_863_870',
#     'model': 'LR8',
#     'placement': 'outdoor'},
#    'last_seen': '2021-05-12T08:26:31Z'}),
#  ('eui-3133303719004400',
#   {'id': 'eui-3133303719004400',
#    'description': 'Gullvivsvägen 9 Vallentuna',
#    'owner': 'indoorhannes',
#    'owners': ['indoorhannes'],
#    'location': {'latitude': 59.54869853,
#     'longitude': 18.07458998,
#     'altitude': 0},
#    'country_code': 'se',
#    'attributes': {'frequency_plan': 'EU_863_870', 'placement': 'indoor'},
#    'last_seen': '2021-05-12T08:26:35Z'}),
#  ('eui-3133303719005000',
#   {'id': 'eui-3133303719005000',
#    'description': 'Kontoret',
#    'owner': 'indoorhannes',
#    'owners': ['indoorhannes'],
#    'location': {'latitude': 59.35578049,
#     'longitude': 17.97452436,
#     'altitude': 0},
#    'country_code': 'se',
#    'attributes': {'frequency_plan': 'EU_863_870', 'placement': 'indoor'},
#    'last_seen': '2021-05-12T08:26:24Z'}),
#  ('eui-313330371a005f00',
#   {'id': 'eui-313330371a005f00',
#    'description': 'ttn-taby-mikrotik',
#    'owner': 'grobius',
#    'owners': ['grobius'],
#    'location': {'latitude': 59.42375345,
#     'longitude': 18.09997886,
#     'altitude': 0},
#    'country_code': 'se',
#    'attributes': {'antenna_model': 'Mikrotik 6.5 dBi Omni antenna',
#     'brand': 'Mikrotik',
#     'frequency_plan': 'EU_863_870',
#     'model': 'wAP LR8',
#     'placement': 'outdoor'},
#    'last_seen': '2021-05-12T08:26:27Z'}),
#  ('eui-313532354a006700',
#   {'id': 'eui-313532354a006700',
#    'description': 'AxByte Älvsjö',
#    'owner': 'axbyte',
#    'owners': ['axbyte'],
#    'location': {'latitude': 59.27152321,
#     'longitude': 18.0067497,
#     'altitude': 53},
#    'country_code': 'se',
#    'attributes': {'antenna_model': 'MikroTik LoRa 6.5 dBi antenna kit',
#     'brand': 'MikroTik',
#     'frequency_plan': 'EU_863_870',
#     'model': 'wAP LoRa8 kit',
#     'placement': 'outdoor'},
#    'last_seen': '2021-05-12T08:26:23Z'}),
#  ('eui-323531322f002500',
#   {'id': 'eui-323531322f002500',
#    'description': 'Skanstull',
#    'owner': 'mala57',
#    'owners': ['mala57'],
#    'location': {'latitude': 59.30704987,
#     'longitude': 18.08055997,
#     'altitude': 30},
#    'country_code': 'se',
#    'attributes': {'frequency_plan': 'EU_863_870', 'placement': 'outdoor'},
#    'last_seen': '2021-05-12T01:18:56Z'}),
#  ('eui-333833301c004a00',
#   {'id': 'eui-333833301c004a00',
#    'description': 'inedal',
#    'owner': 'inedal',
#    'owners': ['inedal'],
#    'location': {'latitude': 59.33490309,
#     'longitude': 18.0349258,
#     'altitude': 12},
#    'country_code': 'se',
#    'attributes': {'brand': 'n-Fuse',
#     'frequency_plan': 'EU_863_870',
#     'model': 'Raspberry Pi based LRWGWX',
#     'placement': 'outdoor'},
#    'last_seen': '2021-05-12T08:26:35Z'}),
#  ('eui-3338333029002400',
#   {'id': 'eui-3338333029002400',
#    'description': 'Hjortywood Heights - TestGW2',
#    'owner': 'molex',
#    'owners': ['molex'],
#    'location': {'latitude': 59.35481619,
#     'longitude': 18.09437699,
#     'altitude': 0},
#    'country_code': 'se',
#    'attributes': {'antenna_model': 'Aurel GP',
#     'brand': 'Raspberry Pi based',
#     'frequency_plan': 'EU_863_870',
#     'model': 'LRWCCx',
#     'placement': 'indoor'},
#    'last_seen': '2021-05-12T08:26:31Z'}),
#  ('eui-40d63cfffe027dfe',
#   {'id': 'eui-40d63cfffe027dfe',
#    'description': 'bandhagen',
#    'owner': 'debugger',
#    'owners': ['debugger'],
#    'location': {'latitude': 59.27099952,
#     'longitude': 18.04779088,
#     'altitude': 45},
#    'country_code': 'se',
#    'attributes': {'antenna_model': 'Mounted on top (3rd) floor balcony facing East',
#     'brand': 'MatchX',
#     'frequency_plan': 'EU_863_870',
#     'model': 'Box MX1701',
#     'placement': 'outdoor'},
#    'last_seen': '2021-05-03T05:56:40Z'}),
#  ('eui-58a0cbfffe800cce',
#   {'id': 'eui-58a0cbfffe800cce',
#    'description': 'The Things Indoor Gateway 1',
#    'owner': 'emiljaregran',
#    'owners': ['emiljaregran'],
#    'location': {'latitude': 59.88819777,
#     'longitude': 17.64934986,
#     'altitude': 32},
#    'country_code': 'se',
#    'attributes': {'antenna_model': 'PCB antenna',
#     'brand': 'The Things Industries',
#     'frequency_plan': 'EU_863_870',
#     'model': 'The Things Indoor Gateway',
#     'placement': 'indoor',
#     'version': '2.0.0'},
#    'last_seen': '2021-05-12T08:23:57Z'}),
#  ('eui-58a0cbfffe800e5b',
#   {'id': 'eui-58a0cbfffe800e5b',
#    'description': 'minihub 1',
#    'owner': 'grovkillen',
#    'owners': ['grovkillen'],
#    'location': {'latitude': 61.77352571,
#     'longitude': 17.01261644,
#     'altitude': 32},
#    'country_code': 'se',
#    'attributes': {'brand': 'The Things Industries',
#     'frequency_plan': 'EU_863_870',
#     'model': 'The Things Indoor Gateway',
#     'placement': 'indoor',
#     'version': '2.0.0'},
#    'last_seen': '2021-05-11T09:04:29Z'}),
#  ('eui-58a0cbfffe801a32',
#   {'id': 'eui-58a0cbfffe801a32',
#    'description': 'Brunnsberg',
#    'owner': 'pebry',
#    'owners': ['pebry'],
#    'location': {'latitude': 61.28402805,
#     'longitude': 13.9236635,
#     'altitude': 5},
#    'country_code': 'se',
#    'attributes': {'antenna_model': 'Internal',
#     'brand': 'The Things Industries',
#     'frequency_plan': 'EU_863_870',
#     'model': 'The Things Indoor Gateway',
#     'placement': 'indoor',
#     'version': '2.0.0'},
#    'last_seen': '2021-05-12T08:26:32Z'}),
#  ('eui-58a0cbfffe801dd0',
#   {'id': 'eui-58a0cbfffe801dd0',
#    'description': 'SpeedApp AB',
#    'location': {'latitude': 59.63275378,
#     'longitude': 16.54850642,
#     'altitude': 0},
#    'country_code': 'se',
#    'attributes': {'brand': 'The Things Industries',
#     'frequency_plan': 'EU_863_870',
#     'model': 'The Things Indoor Gateway',
#     'placement': 'indoor',
#     'version': '2.0.0'},
#    'last_seen': '2021-04-21T23:03:01Z'}),
#  ('eui-58a0cbfffe802190',
#   {'id': 'eui-58a0cbfffe802190',
#    'description': 'Spetby skola',
#    'owner': 'spetbyskola',
#    'owners': ['spetbyskola'],
#    'location': {'latitude': 59.21312771,
#     'longitude': 16.22137978,
#     'altitude': 55},
#    'country_code': 'se',
#    'attributes': {'antenna_model': 'Built in',
#     'brand': 'The Things Industries',
#     'frequency_plan': 'EU_863_870',
#     'model': 'The Things Indoor Gateway',
#     'placement': 'indoor',
#     'version': '2.0.0'},
#    'last_seen': '2021-05-12T08:05:24Z'}),
#  ('eui-58a0cbfffe802a9d',
#   {'id': 'eui-58a0cbfffe802a9d',
#    'description': 'Eklosa gw',
#    'owner': 'gorhoi',
#    'owners': ['gorhoi'],
#    'location': {'latitude': 59.63832823,
#     'longitude': 18.23493513,
#     'altitude': 0},
#    'country_code': 'se',
#    'attributes': {'brand': 'The Things Industries',
#     'frequency_plan': 'EU_863_870',
#     'model': 'The Things Indoor Gateway',
#     'placement': 'indoor',
#     'version': '2.0.0'},
#    'last_seen': '2021-05-12T07:30:28Z'}),
#  ('eui-60c5a8fffe71d210',
#   {'id': 'eui-60c5a8fffe71d210',
#    'description': '60C5A8FFFE71D210 Sweden Demo Kista 915',
#    'location': {'latitude': 59.40537726,
#     'longitude': 17.94574503,
#     'altitude': 0},
#    'country_code': 'se',
#    'attributes': {'brand': 'Tannak International',
#     'frequency_plan': 'US_902_928',
#     'model': 'TLBS-01-4G',
#     'placement': 'outdoor'}}),
#  ('eui-60c5a8fffe71d212',
#   {'id': 'eui-60c5a8fffe71d212',
#    'description': '60C5A8FFFE71D212 Sweden Demo Kista 868',
#    'location': {'latitude': 59.40534826,
#     'longitude': 17.94573655,
#     'altitude': 7},
#    'country_code': 'se',
#    'attributes': {'brand': 'VestiTech',
#     'frequency_plan': 'EU_863_870',
#     'placement': 'indoor'},
#    'last_seen': '2021-05-12T08:26:10Z'}),
#  ('eui-60c5a8fffe7614f0',
#   {'id': 'eui-60c5a8fffe7614f0',
#    'description': 'Senseair RAK01',
#    'owner': 'senseair',
#    'owners': ['senseair'],
#    'location': {'latitude': 61.79646302,
#     'longitude': 16.55854927,
#     'altitude': 0},
#    'country_code': 'se',
#    'attributes': {'brand': 'RAKwireless',
#     'frequency_plan': 'EU_863_870',
#     'model': 'linux - Firmware  - Protocol 2',
#     'placement': 'outdoor'},
#    'last_seen': '2021-04-30T14:45:39Z'}),
#  ('eui-60c5a8fffe783d85',
#   {'id': 'eui-60c5a8fffe783d85',
#    'description': 'RAK7258 Gateway',
#    'owner': 'things_abasto',
#    'owners': ['things_abasto'],
#    'location': {'latitude': 59.63891587,
#     'longitude': 17.7619614,
#     'altitude': 0},
#    'country_code': 'se',
#    'attributes': {'brand': 'RAKwireless',
#     'frequency_plan': 'EU_863_870',
#     'model': '7258',
#     'placement': 'indoor'},
#    'last_seen': '2021-05-12T08:26:10Z'}),
#  ('eui-a840411d23b44150',
#   {'id': 'eui-a840411d23b44150',
#    'description': 'Dragino_Home',
#    'owner': 'trinsic',
#    'owners': ['trinsic'],
#    'location': {'latitude': 59.44103303,
#     'longitude': 13.42785935,
#     'altitude': 0},
#    'country_code': 'se',
#    'attributes': {'brand': 'Dragino',
#     'frequency_plan': 'EU_863_870',
#     'placement': 'indoor'},
#    'last_seen': '2021-05-12T08:26:10Z'}),
#  ('eui-a840411daea84150',
#   {'id': 'eui-a840411daea84150',
#    'location': {'latitude': 60.6546516418457,
#     'longitude': 17.159639358520508,
#     'altitude': 0},
#    'country_code': 'se',
#    'attributes': {'brand': 'Dragino', 'frequency_plan': 'US_902_928'},
#    'last_seen': '2021-05-03T11:51:07Z'}),
#  ('eui-a840411daf784150',
#   {'id': 'eui-a840411daf784150',
#    'description': 'LG02-Gateway-1',
#    'owner': 'marshall-9914-20',
#    'owners': ['marshall-9914-20'],
#    'location': {'latitude': 61.41132304,
#     'longitude': 16.65731607,
#     'altitude': 0},
#    'country_code': 'se',
#    'attributes': {'brand': 'Dragino', 'frequency_plan': 'EU_863_870'},
#    'last_seen': '2021-05-12T08:26:16Z'}),
#  ('eui-a840411dbca84150',
#   {'id': 'eui-a840411dbca84150',
#    'description': 'jornik-gw-2',
#    'owner': 'jornik',
#    'owners': ['jornik'],
#    'location': {'latitude': 59.42996751,
#     'longitude': 18.04306472,
#     'altitude': 0},
#    'country_code': 'se',
#    'attributes': {'brand': 'Dragino', 'frequency_plan': 'EU_863_870'},
#    'last_seen': '2021-05-12T08:26:35Z'}),
#  ('eui-a840411e9a1c4150',
#   {'id': 'eui-a840411e9a1c4150',
#    'description': 'EffarGW',
#    'location': {'latitude': 59.4527611,
#     'longitude': 17.98044405,
#     'altitude': 24},
#    'country_code': 'se',
#    'attributes': {'brand': 'Dragino',
#     'frequency_plan': 'EU_863_870',
#     'model': 'LPS8',
#     'placement': 'indoor'},
#    'last_seen': '2021-05-12T08:26:26Z'}),
#  ('eui-a840411ec2044150',
#   {'id': 'eui-a840411ec2044150',
#    'description': 'Dragino LPS8 Homegateway for developement',
#    'owner': 'jsandberg',
#    'owners': ['jsandberg'],
#    'location': {'latitude': 59.6083781,
#     'longitude': 17.47524846,
#     'altitude': 0},
#    'country_code': 'se',
#    'attributes': {'brand': 'Dragino',
#     'frequency_plan': 'EU_863_870',
#     'model': 'LPS8'},
#    'last_seen': '2021-04-17T17:03:55Z'}),
#  ('eui-ac1f09fffe004f22',
#   {'id': 'eui-ac1f09fffe004f22',
#    'description': 'RAK7249 no 2',
#    'owner': 'grovkillen',
#    'owners': ['grovkillen'],
#    'location': {'latitude': 61.77350302,
#     'longitude': 17.0126401,
#     'altitude': 45},
#    'country_code': 'se',
#    'attributes': {'antenna_model': 'Fiberglass',
#     'brand': 'RAKwireless',
#     'frequency_plan': 'EU_863_870',
#     'model': '7249',
#     'placement': 'outdoor'},
#    'last_seen': '2021-05-12T08:26:26Z'}),
#  ('eui-b827ebfffe1749b6',
#   {'id': 'eui-b827ebfffe1749b6',
#    'description': 'Henriksdalsberget',
#    'owner': 'simply',
#    'owners': ['simply'],
#    'location': {'latitude': 59.309922, 'longitude': 18.113887, 'altitude': 60},
#    'country_code': 'se',
#    'attributes': {'antenna_model': 'GP',
#     'brand': 'Raspberry Pi based',
#     'frequency_plan': 'EU_863_870',
#     'model': 'RAK831',
#     'placement': 'outdoor'},
#    'last_seen': '2021-05-12T08:26:36Z'}),
#  ('eui-b827ebfffe6803c1',
#   {'id': 'eui-b827ebfffe6803c1',
#    'description': 'My home experiment gateway',
#    'owner': 'sm0rvv',
#    'owners': ['sm0rvv'],
#    'location': {'latitude': 59.39963107,
#     'longitude': 17.87000987,
#     'altitude': 3},
#    'country_code': 'se',
#    'attributes': {'antenna_model': '1/4 wave',
#     'brand': 'Raspberry Pi based',
#     'frequency_plan': 'EU_863_870',
#     'model': 'RAK831',
#     'placement': 'indoor'},
#    'last_seen': '2021-05-12T08:26:19Z'}),
#  ('eui-b827ebfffe7d517d',
#   {'id': 'eui-b827ebfffe7d517d',
#    'description': 'PI-ttn-ic880a',
#    'owner': 'mstjerna',
#    'owners': ['mstjerna'],
#    'location': {'latitude': 59.238255, 'longitude': 17.965618, 'altitude': 0},
#    'country_code': 'se',
#    'attributes': {'brand': 'Raspberry Pi based',
#     'frequency_plan': 'EU_863_870',
#     'placement': 'indoor'},
#    'last_seen': '2021-05-12T08:26:24Z'}),
#  ('eui-b827ebfffeb6aad1',
#   {'id': 'eui-b827ebfffeb6aad1',
#    'description': 'RPI+RAK2245',
#    'location': {'latitude': 59.41129549,
#     'longitude': 13.51004899,
#     'altitude': 55},
#    'country_code': 'se',
#    'attributes': {'antenna_model': '1/2 wave',
#     'brand': 'Raspberry Pi based',
#     'frequency_plan': 'EU_863_870',
#     'model': 'RAK2245',
#     'placement': 'indoor'},
#    'last_seen': '2021-04-22T16:13:13Z'}),
#  ('eui-b827ebfffebbf8bb',
#   {'id': 'eui-b827ebfffebbf8bb',
#    'description': 'Stuvaregatan Gavle Sweden',
#    'owner': 'slaskhas',
#    'owners': ['slaskhas'],
#    'location': {'latitude': 60.67985331,
#     'longitude': 17.1699362,
#     'altitude': 3},
#    'country_code': 'se',
#    'attributes': {'brand': 'Raspberry Pi based',
#     'frequency_plan': 'EU_863_870',
#     'model': 'IMST',
#     'placement': 'indoor'},
#    'last_seen': '2021-05-12T08:26:29Z'}),
#  ('eui-b827ebfffedb2680',
#   {'id': 'eui-b827ebfffedb2680',
#    'description': 'CE-GW001',
#    'location': {'latitude': 59.37398787,
#     'longitude': 18.01080287,
#     'altitude': 24},
#    'country_code': 'se',
#    'attributes': {'brand': 'Raspberry Pi based',
#     'frequency_plan': 'EU_863_870',
#     'model': 'RAK831',
#     'placement': 'indoor'},
#    'last_seen': '2021-05-12T08:26:20Z'}),
#  ('eui-b827ebfffedf20e3',
#   {'id': 'eui-b827ebfffedf20e3',
#    'description': 'Tranholmen',
#    'owner': 'mellbratt',
#    'owners': ['mellbratt'],
#    'location': {'latitude': 59.375396239550696,
#     'longitude': 18.08698163585666,
#     'altitude': 30},
#    'country_code': 'se',
#    'attributes': {'antenna_model': 'Taoglas OMB',
#     'brand': 'Raspberry Pi based',
#     'frequency_plan': 'EU_863_870',
#     'model': 'IMST',
#     'placement': 'indoor'},
#    'last_seen': '2021-05-12T08:26:10Z'}),
#  ('eui-b827ebffff95ea42',
#   {'id': 'eui-b827ebffff95ea42',
#    'description': 'Jakobsberg single frequency gateway',
#    'owner': 'andy1551',
#    'owners': ['andy1551'],
#    'location': {'latitude': 59.42916919,
#     'longitude': 17.82482319,
#     'altitude': 40},
#    'country_code': 'se',
#    'attributes': {'antenna_model': 'lambda/4 Ground Plane',
#     'brand': 'Raspberry Pi based',
#     'frequency_plan': 'EU_863_870',
#     'model': 'Pi3 with Dragino shield, 868.1 MHz, SF12',
#     'placement': 'indoor'},
#    'last_seen': '2021-05-12T08:26:12Z'}),
#  ('eui-c0ee40ffff29356b',
#   {'id': 'eui-c0ee40ffff29356b',
#    'description': 'KELLER Laird LoRa Gateway @Keller Sweden',
#    'owner': 'kellersweden',
#    'owners': ['kellersweden'],
#    'location': {'latitude': 59.95414039,
#     'longitude': 17.54236304,
#     'altitude': 4},
#    'country_code': 'se',
#    'attributes': {'antenna_model': 'Aurel GP',
#     'brand': 'Laird',
#     'frequency_plan': 'EU_863_870',
#     'model': 'Sentrius RG1xx',
#     'placement': 'indoor'},
#    'last_seen': '2021-05-12T08:26:32Z'}),
#  ('eui-c0ee40ffff2976d7',
#   {'id': 'eui-c0ee40ffff2976d7',
#    'description': 'Växtväggsövervakning',
#    'owner': 'greenworks',
#    'owners': ['greenworks'],
#    'location': {'latitude': 59.31161534,
#     'longitude': 18.07602614,
#     'altitude': 0},
#    'country_code': 'se',
#    'attributes': {'brand': 'Laird',
#     'frequency_plan': 'EU_863_870',
#     'placement': 'indoor'},
#    'last_seen': '2021-04-15T04:15:43Z'}),
#  ('eui-c82319faab120912',
#   {'id': 'eui-c82319faab120912',
#    'description': 'ABGw',
#    'owner': 'andreasbergkvist',
#    'owners': ['andreasbergkvist'],
#    'location': {'latitude': 60.60981727,
#     'longitude': 15.62370892,
#     'altitude': 0},
#    'country_code': 'se',
#    'attributes': {'frequency_plan': 'EU_863_870', 'placement': 'indoor'},
#    'last_seen': '2021-05-12T08:25:16Z'}),
#  ('eui-dca632fffe6aad50',
#   {'id': 'eui-dca632fffe6aad50',
#    'description': 'Odenslätt GW',
#    'owner': 'hasse1989',
#    'owners': ['hasse1989'],
#    'location': {'latitude': 60.38985191,
#     'longitude': 17.4211827,
#     'altitude': 0},
#    'country_code': 'se',
#    'attributes': {'antenna_model': '5 db Fiber',
#     'brand': 'RAKwireless',
#     'frequency_plan': 'EU_863_870',
#     'model': '7244p',
#     'placement': 'outdoor'},
#    'last_seen': '2021-05-12T08:26:16Z'}),
#  ('eui-fcc23dfffe206746',
#   {'id': 'eui-fcc23dfffe206746',
#    'description': 'Lorix-Färingsö',
#    'location': {'latitude': 59.41790468,
#     'longitude': 17.66293552,
#     'altitude': 10},
#    'country_code': 'se',
#    'attributes': {'antenna_model': 'Procom CXL 900-3LW-NB',
#     'brand': 'Lorix',
#     'frequency_plan': 'EU_863_870',
#     'model': 'One',
#     'placement': 'outdoor'},
#    'last_seen': '2021-05-12T08:26:23Z'}),
#  ('eui-fcc23dfffe209fa2',
#   {'id': 'eui-fcc23dfffe209fa2',
#    'description': 'SLU-Siljansfors3 (LorixOne)',
#    'owner': 'olalangvall',
#    'owners': ['olalangvall'],
#    'location': {'latitude': 60.89220185,
#     'longitude': 14.37481712,
#     'altitude': 0},
#    'country_code': 'se',
#    'attributes': {'frequency_plan': 'EU_863_870', 'placement': 'outdoor'},
#    'last_seen': '2021-05-12T08:26:19Z'}),
#  ('eui-fcc23dfffe20ded8',
#   {'id': 'eui-fcc23dfffe20ded8',
#    'description': 'SLU-Siljansfors2 (LorixOne)',
#    'owner': 'olalangvall',
#    'owners': ['olalangvall'],
#    'location': {'latitude': 60.88072853,
#     'longitude': 14.38528352,
#     'altitude': 0},
#    'country_code': 'se',
#    'attributes': {'frequency_plan': 'EU_863_870', 'placement': 'outdoor'},
#    'last_seen': '2021-05-12T08:26:17Z'}),
#  ('loragw1_limetransit_com',
#   {'id': 'loragw1_limetransit_com',
#    'description': 'loragw1.limetransit.com',
#    'owner': 'sverker',
#    'owners': ['sverker'],
#    'location': {'latitude': 59.35926447,
#     'longitude': 18.0003232,
#     'altitude': 15},
#    'country_code': 'se',
#    'attributes': {'brand': 'Raspberry Pi based',
#     'frequency_plan': 'EU_863_870',
#     'model': 'PiSupply',
#     'placement': 'indoor'},
#    'last_seen': '2021-05-12T08:26:26Z'}),
#  ('modigdesign',
#   {'id': 'modigdesign',
#    'description': 'Modig Design Development Gateway',
#    'owner': 'ulfmodig',
#    'owners': ['ulfmodig'],
#    'location': {'latitude': 59.3708158,
#     'longitude': 17.20866635,
#     'altitude': 0},
#    'attributes': {'antenna_model': 'DeLock 89583',
#     'brand': 'Raspberry Pi based',
#     'frequency_plan': 'EU_863_870',
#     'model': 'PiSupply',
#     'placement': 'outdoor'},
#    'last_seen': '2021-05-12T08:26:33Z'}),
#  ('rg1xx293bf9',
#   {'id': 'rg1xx293bf9',
#    'description': 'Addiva Lora',
#    'owner': 'einarmattsonpilot',
#    'owners': ['einarmattsonpilot'],
#    'location': {'latitude': 59.60596856,
#     'longitude': 16.55294575,
#     'altitude': 0},
#    'country_code': 'se',
#    'attributes': {'brand': 'Laird',
#     'frequency_plan': 'EU_863_870',
#     'model': 'Sentrius RG186',
#     'placement': 'indoor'},
#    'last_seen': '2021-05-12T08:26:35Z'}),
#  ('sa_lora01',
#   {'id': 'sa_lora01',
#    'description': 'Senseair AB_01',
#    'owner': 'senseair',
#    'owners': ['senseair'],
#    'location': {'latitude': 61.70998317,
#     'longitude': 16.63796251,
#     'altitude': 110},
#    'country_code': 'se',
#    'attributes': {'antenna_model': 'Aurel GP',
#     'brand': 'The Things Products',
#     'frequency_plan': 'EU_863_870',
#     'model': 'The Things Gateway',
#     'placement': 'indoor',
#     'version': 'v1.0.8-846da98b'},
#    'last_seen': '2021-05-12T08:26:17Z'}),
#  ('se-sto-bbt01',
#   {'id': 'se-sto-bbt01',
#    'description': 'Pi Supply GW',
#    'owner': 'foo8ar',
#    'owners': ['foo8ar'],
#    'location': {'latitude': 59.52188, 'longitude': 17.848204, 'altitude': 19},
#    'country_code': 'se',
#    'attributes': {'brand': 'Raspberry Pi based',
#     'frequency_plan': 'EU_863_870',
#     'model': 'PiSupply',
#     'placement': 'outdoor'},
#    'last_seen': '2021-05-12T08:26:20Z'}),
#  ('strucknet01',
#   {'id': 'strucknet01',
#    'owner': 'strucknet',
#    'owners': ['strucknet'],
#    'location': {'latitude': 59.39828926,
#     'longitude': 17.89548336,
#     'altitude': 0},
#    'country_code': 'se',
#    'attributes': {'brand': 'The Things Products',
#     'frequency_plan': 'EU_863_870',
#     'model': 'The Things Gateway',
#     'placement': 'indoor',
#     'version': 'v1.0.8-846da98b'},
#    'last_seen': '2021-05-12T08:26:32Z'}),
#  ('tbg-ttn-gw-1',
#   {'id': 'tbg-ttn-gw-1',
#    'description': 'tbg-ttn-gw-1',
#    'owner': 'mist',
#    'owners': ['mist'],
#    'location': {'latitude': 59.4819448,
#     'longitude': 17.9251273,
#     'altitude': 26},
#    'country_code': 'se',
#    'attributes': {'brand': 'Raspberry Pi based',
#     'frequency_plan': 'EU_863_870',
#     'model': 'IMST',
#     'placement': 'indoor'},
#    'last_seen': '2021-05-12T08:26:18Z'})]

# %%
temp{"akersberga_1"}
# Out:
#   File "<ipython-input-32-85d571d10c92>", line 1
#     temp{"akersberga_1"}
#         ^
# SyntaxError: invalid syntax

# %%
[sub['akersberga_1'] for sub in temp ]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-9c2403c6ed66> in <module>
# ----> 1 [ sub['akersberga_1'] for sub in temp ]
#
# <ipython-input-29-9c2403c6ed66> in <listcomp>(.0)
# ----> 1 [ sub['akersberga_1'] for sub in temp ]
#
# TypeError: tuple indices must be integers or slices, not str
